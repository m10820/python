# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect("sakila (1).db")

# %%
# Set SQL query as a comment
sql_query = ''' SELECT * FROM customer '''

# Use pandas to pass sql query using connection form SQLite3
df = pd.read_sql(sql_query, con)

# Show the resulting DataFrame
df.head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0            1         1       MARY     SMITH
# 1            2         1   PATRICIA   JOHNSON
# 2            3         1      LINDA  WILLIAMS
# 3            4         2    BARBARA     JONES
# 4            5         1  ELIZABETH     BROWN
#
#                                  email  address_id active  \
# 0        MARY.SMITH@sakilacustomer.org           5      1
# 1  PATRICIA.JOHNSON@sakilacustomer.org           6      1
# 2    LINDA.WILLIAMS@sakilacustomer.org           7      1
# 3     BARBARA.JONES@sakilacustomer.org           8      1
# 4   ELIZABETH.BROWN@sakilacustomer.org           9      1
#
#                create_date          last_update
# 0  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 1  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 2  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 3  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 4  2006-02-14 22:04:36.000  2011-09-14 18:10:28

# %%
def sql_to_df(query):
    df = pd.read_sql(query,con)
    return df

# %%
q = ''' SELECT first_name,last_name FROM customer; '''
sql_to_df(q).head()
# Out:
#   first_name last_name
# 0       MARY     SMITH
# 1   PATRICIA   JOHNSON
# 2      LINDA  WILLIAMS
# 3    BARBARA     JONES
# 4  ELIZABETH     BROWN

# %%
#DISTINCT in sql means unique values

# %%
q = ''' SELECT DISTINCT(country_id) FROM city '''

# %%
sql_to_df(q)
# Out:
#      country_id
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
# ..          ...
# 104         105
# 105         106
# 106         107
# 107         108
# 108         109
#
# [109 rows x 1 columns]

# %%
q = ''' SELECT *
        FROM customer
        WHERE first_name = 'MARY' '''

# %%
sql_to_df(q)
# Out:
#    customer_id  store_id first_name last_name                          email  \
# 0            1         1       MARY     SMITH  MARY.SMITH@sakilacustomer.org
#
#    address_id active              create_date          last_update
# 0           5      1  2006-02-14 22:04:36.000  2011-09-14 18:10:28

# %%
q = ''' SELECT *
        FROM customer
        WHERE store_id = 1 '''

# %%
sql_to_df(q)
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       MARY      SMITH
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              5         1  ELIZABETH      BROWN
# 4              7         1      MARIA     MILLER
# ..           ...       ...        ...        ...
# 321          594         1    EDUARDO      HIATT
# 322          595         1   TERRENCE  GUNDERSON
# 323          596         1    ENRIQUE   FORSYTHE
# 324          597         1    FREDDIE     DUGGAN
# 325          598         1       WADE   DELVALLE
#
#                                      email  address_id active  \
# 0            MARY.SMITH@sakilacustomer.org           5      1
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6      1
# 2        LINDA.WILLIAMS@sakilacustomer.org           7      1
# 3       ELIZABETH.BROWN@sakilacustomer.org           9      1
# ...

# %%
#for choosing a specific cell use'Mary' to get cell with name mary

# %%
q = ''' SELECT AVG(customer_id)
        FROM customer; '''

# %%
sql_to_df(q)
# Out:
#    AVG(customer_id)
# 0             300.0

# %%
## % for 0 or more characters
## _ for a single character
## [] for sets and ranges of character to match

# %%
q = ''' SELECT *
        FROM customer
        WHERE first_name LIKE 'M%' ; '''
#every first name starting from M

sql_to_df(q)
# Out:
#     customer_id  store_id first_name     last_name  \
# 0             1         1       MARY         SMITH
# 1             7         1      MARIA        MILLER
# 2             9         2   MARGARET         MOORE
# 3            21         1   MICHELLE         CLARK
# 4            30         1    MELISSA          KING
# 5            38         1     MARTHA      GONZALEZ
# 6            44         1      MARIE        TURNER
# 7            60         1    MILDRED        BAILEY
# 8            80         1    MARILYN          ROSS
# 9           128         1   MARJORIE        TUCKER
# 10          131         2     MONICA         HICKS
# 11          151         2      MEGAN        PALMER
# 12          154         2    MICHELE         GRANT
# 13          178         2     MARION        SNYDER
# 14          188         1    MELANIE     ARMSTRONG
# 15          223         1    MELINDA     FERNANDEZ
# 16          226         2    MAUREEN        LITTLE
# ...

# %%
q = ''' SELECT *
        FROM customer
        WHERE last_name LIKE '_ING' ; '''
# every lastname end with ing having only 1 character before ing
sql_to_df(q)
# Out:
#    customer_id  store_id first_name last_name  \
# 0           30         1    MELISSA      KING
#
#                              email  address_id active  \
# 0  MELISSA.KING@sakilacustomer.org          34      1
#
#                create_date          last_update
# 0  2006-02-14 22:04:36.000  2011-09-14 18:10:29

# %%
q = ''' SELECT *
        FROM customer
        WHERE first_name LIKE 'MA%' ; '''

sql_to_df(q)
# Out:
#     customer_id  store_id first_name last_name  \
# 0             1         1       MARY     SMITH
# 1             7         1      MARIA    MILLER
# 2             9         2   MARGARET     MOORE
# 3            38         1     MARTHA  GONZALEZ
# 4            44         1      MARIE    TURNER
# 5            80         1    MARILYN      ROSS
# 6           128         1   MARJORIE    TUCKER
# 7           178         2     MARION    SNYDER
# 8           226         2    MAUREEN    LITTLE
# 9           236         1     MARCIA      DEAN
# 10          240         1    MARLENE     WELCH
# 11          246         1     MARIAN   MENDOZA
# 12          252         2     MATTIE   HOFFMAN
# 13          254         2     MAXINE     SILVA
# 14          256         2      MABEL   HOLLAND
# 15          257         2     MARSHA   DOUGLAS
# 16          267         1     MARGIE      WADE
# 17          293         2        MAE  FLETCHER
# 18          312         2       MARK  RINEHART
# ...

# %%
#select customer whose name begin with either a or b
#character list
q = ''' SELECT *
        FROM customer
        WHERE first_name GLOB '[AB]*' ; '''

sql_to_df(q)
# Out:
#     customer_id  store_id first_name  last_name  \
# 0             4         2    BARBARA      JONES
# 1            14         2      BETTY      WHITE
# 2            29         2     ANGELA  HERNANDEZ
# 3            31         2     BRENDA     WRIGHT
# 4            32         1        AMY      LOPEZ
# ..          ...       ...        ...        ...
# 71          567         2    ALFREDO    MCADAMS
# 72          568         2    ALBERTO    HENNING
# 73          573         1      BYRON        BOX
# 74          582         2       ANDY    VANHORN
# 75          599         2     AUSTIN    CINTRON
#
#                                   email  address_id active  \
# 0      BARBARA.JONES@sakilacustomer.org           8      1
# 1        BETTY.WHITE@sakilacustomer.org          18      1
# 2   ANGELA.HERNANDEZ@sakilacustomer.org          33      1
# 3      BRENDA.WRIGHT@sakilacustomer.org          35      1
# 4          AMY.LOPEZ@sakilacustomer.org          36      1
# ...

# %%
q = ''' SELECT *
        FROM customer
        ORDER BY last_name DESC ; '''

sql_to_df(q)
#alphabetic order
# Out:
#      customer_id  store_id first_name  last_name  \
# 0             28         1    CYNTHIA      YOUNG
# 1            413         2     MARVIN        YEE
# 2            402         1       LUIS      YANEZ
# 3            318         1      BRIAN      WYMAN
# 4             31         2     BRENDA     WRIGHT
# ..           ...       ...        ...        ...
# 594          470         1     GORDON     ALLARD
# 595           96         1      DIANA  ALEXANDER
# 596           36         2   KATHLEEN      ADAMS
# 597          504         1  NATHANIEL       ADAM
# 598          505         1     RAFAEL      ABNEY
#
#                                   email  address_id active  \
# 0      CYNTHIA.YOUNG@sakilacustomer.org          32      1
# 1         MARVIN.YEE@sakilacustomer.org         418      1
# 2         LUIS.YANEZ@sakilacustomer.org         407      1
# 3        BRIAN.WYMAN@sakilacustomer.org         323      1
# 4      BRENDA.WRIGHT@sakilacustomer.org          35      1
# ...

# %%
#group result by one or more columns
#count number of customers per store
q = ''' SELECT store_id , COUNT(customer_id)
        FROM customer
        GROUP BY store_id; '''

sql_to_df(q)
# Out:
#    store_id  COUNT(customer_id)
# 0         1                 326
# 1         2                 273

# %%
q = ''' SELECT store_id , COUNT(customer_id)
        FROM customer; '''

sql_to_df(q)
# Out:
#    store_id  COUNT(customer_id)
# 0         1                 599
