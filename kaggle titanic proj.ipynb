# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame,Series
# %matplotlib inline

# %%
titanic_df = pd.read_csv('train.csv')

# %%
titanic_df.head()
#sibsp siblings on board
#parch parents or children on board
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
import warnings
warnings.simplefilter("ignore")


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#Q who were the passengers on titanic

# %%
#sex count on titanic

# %%
sns.histplot(titanic_df,x='Sex')
#clearly there are more males
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Count'>

# %%
#sex and pclass they were in

# %%
sns.histplot(data=titanic_df,x='Sex',hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Count'>

# %%
#gender acc to pclass

# %%
sns.histplot(data=titanic_df,x='Pclass',hue='Sex')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Count'>

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#apply technique
def m_f_child(passenger):
    age,sex = passenger
    if age < 16:
        return 'child'
    else:
        return sex

# %%
titanic_df['person'] = titanic_df[['Age','Sex']].apply(m_f_child,axis=1)
#this is a column not an index so remember to put axis
#grabbing age sex column values and then applying above func

# %%
titanic_df[0:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#gender,cjhild acc to class

# %%
sns.histplot(x='Pclass',data= titanic_df,hue='person')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Count'>

# %%
#diff age of people on board

# %%
titanic_df['Age'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic_df['person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
#gender of child

# %%
sns.histplot(titanic_df[titanic_df['person']=='child'],x='person',hue='Sex')
# Out:
# <AxesSubplot:xlabel='person', ylabel='Count'>

# %%
#kde plot on ages on male versus female

# %%
#facet plot allows to do multiple plot on one figure
#aspect argument set aspect ratio , it looks nice and strech fig plot
fig = sns.FacetGrid(titanic_df,hue='Sex',aspect=4)
#map kde plots from age column
fig.map(sns.kdeplot,'Age',shade= True)

oldest = titanic_df['Age'].max()

#set limit
fig.set(xlim=(0,oldest))

#manually add legend
fig.add_legend()

# %%
#age distribution for children male nd female

# %%
#facet plot allows to do multiple plot on one figure
#aspect argument set aspect ratio , it looks nice and strech fig plot
fig = sns.FacetGrid(titanic_df,hue='person',aspect=4)
#map kde plots from age column
fig.map(sns.kdeplot,'Age',shade= True)

oldest = titanic_df['Age'].max()

#set limit
fig.set(xlim=(0,oldest))

#manually add legend
fig.add_legend()

# %%
#kde plots have bandwidth which is why child is going up mark of 16

# %%
#ages arranged by class

# %%
#facet plot allows to do multiple plot on one figure
#aspect argument set aspect ratio , it looks nice and strech fig plot
fig = sns.FacetGrid(titanic_df,hue='Pclass',aspect=4)
#map kde plots from age column
fig.map(sns.kdeplot,'Age',shade= True)

oldest = titanic_df['Age'].max()

#set limit
fig.set(xlim=(0,oldest))

#manually add legend
fig.add_legend()

# %%
#2nd 3rd class skew more towards 20-30 range
#1st class has normal distribution

# %%
#Q what deck were passengers on & how they relate to thier class

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
#first step is to drop null values

# %%
deck=titanic_df['Cabin'].dropna()

# %%
deck.count()
# Out:
# 204

# %%
new_info = DataFrame(deck)

# %%
deck.head()
# Out:
# 1      C85
# 3     C123
# 6      E46
# 10      G6
# 11    C103
# Name: Cabin, dtype: object

# %%
levels=[]
for num in i:
        levels.append(deck.iloc[num][0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [41], in <cell line: 2>()
#       1 levels=[]
#       2 for num in i:
# ----> 3         levels.append(deck.iloc[num][0])
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1520, in _iLocIndexer._getitem_axis(self, key, axis)
#    1517     raise TypeError("Cannot index by location index with a non-integer key")
#    1519 # validate the location
# -> 1520 self._validate_integer(key, axis)
#    1522 return self.obj._ixs(key, axis=axis)
#
# ...

# %%
len(levels)
# Out:
# 204

# %%
cabin_df = DataFrame(levels)
cabin_df.columns = ['Cabin']
#gives dframe with column index and  cabin

# %%
cabin_df
# Out:
#     Cabin
# 0       C
# 1       C
# 2       E
# 3       G
# 4       C
# 5       D
# 6       A
# 7       C
# 8       B
# 9       D
# 10      B
# 11      C
# 12      B
# 13      C
# 14      F
# 15      F
# 16      C
# 17      E
# 18      A
# 19      D
# 20      D
# 21      C
# 22      B
# 23      E
# 24      D
# 25      F
# 26      D
# 27      C
# 28      B
# 29      F
# 30      C
# 31      E
# 32      B
# 33      A
# 34      C
# 35      F
# 36      A
# 37      F
# 38      B
# 39      B
# 40      G
# 41      A
# 42      D
# 43      D
# 44      C
# 45      C
# 46      C
# 47      D
# 48      G
# 49      C
# 50      B
# 51      E
# 52      B
# 53      C
# 54      C
# 55      C
# 56      D
# 57      A
# 58      B
# 59      D
# 60      C
# 61      C
# 62      B
# 63      E
# 64      C
# 65      C
# 66      E
# 67      C
# 68      B
# 69      C
# 70      E
# 71      C
# 72      D
# 73      B
# 74      C
# 75      C
# 76      C
# 77      E
# 78      T
# 79      F
# 80      C
# 81      F
# ...

# %%
cabin_df.index
# Out:
# RangeIndex(start=0, stop=204, step=1)

# %%
sns.catplot(x=,data=cabin_df,palette='winter_d',kind='bar')
# Out:
#   Input In [46]
#     sns.catplot(x=,data=cabin_df,palette='winter_d',kind='bar')
#                   ^
# SyntaxError: invalid syntax

# %%
sns.histplot(cabin_df,x='Cabin')
# Out:
# <AxesSubplot:xlabel='Cabin', ylabel='Count'>

# %%
#drop T
cabin_df = cabin_df[cabin_df.Cabin != 'T']

# %%
sns.histplot(cabin_df,x='Cabin')
# Out:
# <AxesSubplot:xlabel='Cabin', ylabel='Count'>

# %%
#embarked stands for city names

# %%
sns.histplot(data=titanic_df,x='Embarked',hue='Pclass',
             multiple='dodge',shrink=.8)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Count'>

# %%
##Q whos alone whos with family

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
titanic_df['Alone']= titanic_df.SibSp + titanic_df.Parch

# %%
titanic_df['Alone']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       4
# 8       2
# 9       1
# 10      2
# 11      0
# 12      0
# 13      6
# 14      0
# 15      0
# 16      5
# 17      0
# 18      1
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      4
# 25      6
# 26      0
# 27      5
# 28      0
# 29      0
# 30      0
# 31      1
# 32      0
# 33      0
# 34      1
# 35      1
# 36      0
# 37      0
# 38      2
# 39      1
# 40      1
# 41      1
# 42      0
# 43      3
# 44      0
# 45      0
# 46      1
# 47      0
# 48      2
# 49      1
# 50      5
# 51      0
# 52      1
# 53      1
# 54      1
# 55      0
# 56      0
# 57      0
# 58      3
# 59      7
# 60      0
# 61      0
# 62      1
# 63      5
# 64      0
# 65      2
# 66      0
# 67      0
# 68      6
# 69      2
# 70      0
# 71      7
# 72      0
# 73      1
# 74      0
# 75      0
# 76      0
# 77      0
# 78      2
# 79      0
# 80      0
# 81      0
# 82      0
# ...

# %%
titanic_df['Alone'].loc[titanic_df['Alone']>0] = 'With Family'

# %%
titanic_df['Alone'].loc[titanic_df['Alone']==0] = 'Alone'

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person        Alone
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.catplot('Alone',data=titanic_df,kind='count',palette='Blues')
#count of people with fam n alone

# %%
sns.catplot('Alone',data=titanic_df,kind='count',
            palette='Blues',hue='Survived')
#mostly people who were alone died

# %%
titanic_df['Survivor'] = titanic_df.Survived.map({0:'no',1:'yes'})

sns.catplot('Survivor',data=titanic_df,palette='Set1',
            kind='count')

# %%
sns.catplot('Survivor',data=titanic_df,palette='Set1',
            kind='count',hue='Pclass')
#mostly people from 3rd class didnt survive

# %%
#better visualisation
sns.catplot(x='Pclass',y='Survived',data=titanic_df,kind='bar')

#general survival trend for rates of 3rd class are substanitally low

# %%
sns.catplot('person','Survived',data=titanic_df,kind='bar')
#mostly female survived

# %%
sns.catplot(x='Pclass',y='Survived',data=titanic_df,hue='person',kind='bar')

# %%
#linear plot to find relation between above with age factor

# %%
sns.lmplot('Age','Survived',data=titanic_df)
#up on 1.0 we have people who survived
#down at 0.0 all the people that died
#older the passenger less likely were they to survive

# %%
sns.lmplot('Age','Survived',hue='Pclass',data=titanic_df,
           palette='winter')
#bit more deaths in 3rd class

# %%
#clean up above data a little
generations =[10,20,40,60,80,100]

sns.lmplot('Age','Survived',hue='Pclass',data=titanic_df,
          palette='winter',x_bins=generations)
#a high standard deviation on older people in 1st class

# %%
sns.lmplot('Age','Survived',data=titanic_df,hue='Sex',x_bins=generations)
#older female have better chance of survival then older man

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
#q did deck have effect on passenger survival rate

# %%
sns.catplot('Pclass',hue='Survived',data=titanic_df,kind='count')
#clearly most chances of survival was on 1st class
#worst chances on 2nd class which is shocking
#it was presummed people on higher deck probably had a better survival rate

# %%
sns.catplot(x='Cabin',data=cabin_df,hue=titanic_df.Survived,kind='count')
#on deck A survivor chances were the most
#most survivors are on deck C followed by deck B
#least survival rate on G deck followed by
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [74], in <cell line: 1>()
# ----> 1 sns.catplot(x='Cabin',data=cabin_df,hue=titanic_df.Survived,kind='count')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'person', 'Alone',
#        'Survivor'],
#       dtype='object')

# %%
new_info.columns
# Out:
# Index(['Cabin'], dtype='object')

# %%
new_df = pd.merge(titanic_df,new_info,right_index=True,left_index=True)

# %%
new_df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 31            32         1       1
# 52            53         1       1
# 54            55         0       1
# 55            56         1       1
# 61            62         1       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# ...

# %%
def cabin_alph(inf):
    bol = []
    for i in inf:
        if len(i) == 1:
            bol.append(i[0])
        elif len(i) >1:
            bol.append(i[0][0])
            
    return bol

# %%
cabin_alph(new_df['Cabin_x'])
# Out:
# ['C',
#  'C',
#  'E',
#  'G',
#  'C',
#  'D',
#  'A',
#  'C',
#  'B',
#  'D',
#  'B',
#  'C',
#  'B',
#  'C',
#  'F',
#  'F',
#  'C',
#  'E',
#  'A',
#  'D',
#  'D',
#  'C',
#  'B',
#  'E',
#  'D',
#  'F',
#  'D',
#  'C',
#  'B',
#  'F',
#  'C',
#  'E',
#  'B',
#  'A',
#  'C',
#  'F',
#  'A',
#  'F',
#  'B',
#  'B',
#  'G',
#  'A',
#  'D',
#  'D',
#  'C',
#  'C',
#  'C',
#  'D',
#  'G',
#  'C',
#  'B',
#  'E',
#  'B',
#  'C',
#  'C',
#  'C',
#  'D',
#  'A',
#  'B',
#  'D',
#  'C',
#  'C',
#  'B',
#  'E',
#  'C',
#  'C',
#  'E',
#  'C',
#  'B',
#  'C',
#  'E',
#  'C',
#  'D',
#  'B',
#  'C',
#  'C',
#  'C',
#  'E',
#  'T',
#  'F',
#  'C',
#  'F',
#  'C',
#  'E',
#  'D',
#  'B',
#  'E',
#  'C',
#  'B',
#  'D',
#  'G',
#  'C',
#  'E',
#  'C',
#  'E',
#  'B',
#  'C',
#  'A',
#  'C',
#  'C',
#  'C',
#  'E',
#  'D',
#  'E',
#  'E',
#  'D',
#  'A',
#  'B',
#  'C',
#  'B',
#  'C',
#  'D',
#  'C',
#  'B',
#  'C',
#  'E',
#  'D',
#  'F',
#  'B',
#  'B',
#  'C',
#  'B',
#  'B',
#  'B',
#  'C',
# ...

# %%
new_df['New_col']=cabin_alph(new_df['Cabin_x'])

# %%
new_df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 31            32         1       1
# 52            53         1       1
# 54            55         0       1
# 55            56         1       1
# 61            62         1       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# ...

# %%
new_df.drop(['Cabin_x','Cabin_y'], axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 31            32         1       1
# 52            53         1       1
# 54            55         0       1
# 55            56         1       1
# 61            62         1       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# ...

# %%
sns.catplot('New_col',data=new_df,kind='count',hue='Survived')

# %%
#Q did having a family member increase odds of surviving

# %%
sns.catplot(y='Alone',data=titanic_df,x='Survived',kind='bar')
#chances of surviving for people with family are higher

# %%
#done here
